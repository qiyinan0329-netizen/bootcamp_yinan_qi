# %% [markdown]
# # Stage 16 Homework Starter
#
# This notebook is a starting point for polishing your final repo and lifecycle mapping.

# %% [markdown]
# ## Checklist Template
#  - Add checklist elements, as in the examples below, to make sure you cover everything you would like to accomplish
# - Update this checklist as you finalize your repo.

# %%
checklist = {
    "repo_clean": False,
    "repo_complete": False,
    "readme_complete": False,
    "lifecycle_map": False,
    "summary_doc": False,
    "framework_guide_table": False
}
checklist
# Out:
# {'repo_clean': False,
#  'repo_complete': False,
#  'readme_complete': False,
#  'lifecycle_map': False,
#  'summary_doc': False,
#  'framework_guide_table': False}

# %% [markdown]
# ## Reflection Prompts
# - What stage of the lifecycle was hardest for you, and why?
#   - The hardest part was Stage 10 modeling. In 10a, implementing linear regression and interpreting residuals, rolling features, and bootstrapped CIs was challenging. In 10b, time-series and classification tasks added complexity, requiring careful lag features, chronological splits, and metric evaluation.
#
# - Which part of your repo is most reusable in a future project?
#   - The most reusable part of my repo is the model training and prediction pipeline, including imputation, fitting, and bootstrapping functions. These modules can be reused in future regression projects with minimal changes. The plotting functions and Streamlit dashboard are also handy templates for quick interactive visualizations.
#
# - If a teammate had to pick up your repo tomorrow, what would help them most?
#   - If a teammate had to pick up my repo tomorrow, the most helpful things would be a clear README, the modular structure with each task in separate functions or scripts, example data files, and comments explaining assumptions. Overall, focusing on modularity and documentation made the repo easier to hand off.
