# %% [markdown]
# # Homework Starter — Stage 14: Deployment & Monitoring
#
# Use this template to draft your reflection and (optionally) sketch a dashboard.

# %% [markdown]
# ## 1) Reflection (200–300 words)
# If we deploy our current model, there are a few risks. On the data side, new inputs could look different from what the model saw in training, or some values could be missing or wrong. On the model side, it could give bad predictions if it sees unusual inputs or if the data changes over time. System risks include server problems, slow responses, or errors in the dashboard. At the business level, wrong predictions could lead to poor decisions or losses.
#
# To keep things safe, I would monitor four layers. Data: watch for missing values, outliers, or shifts in distributions. Model: track prediction errors and check if retraining is needed. System: keep an eye on uptime, speed, and errors. Business: compare predictions to real outcomes and flag big differences.
#
# Maintenance should be handled by a data science or operations team. Handoffs need clear documentation: code, trained model, feature info, and monitoring steps. The team should meet regularly to make sure the model stays useful, and any updates should be tested before going live.

# %% [markdown]
# ## 2) Optional: Dashboard Sketch
# Describe panels and key charts. You can also attach an image file in your repo (png/pdf).

# %%
# Optional helper: simple structure to list metrics
monitoring = {
    'data': ['freshness_minutes', 'null_rate', 'schema_hash'],
    'model': ['rolling_mae_or_auc', 'calibration_error'],
    'system': ['p95_latency_ms', 'error_rate'],
    'business': ['approval_rate', 'bad_rate']
}
monitoring
# Out:
# {'data': ['freshness_minutes', 'null_rate', 'schema_hash'],
#  'model': ['rolling_mae_or_auc', 'calibration_error'],
#  'system': ['p95_latency_ms', 'error_rate'],
#  'business': ['approval_rate', 'bad_rate']}
