# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# %% [markdown]
# # Warm-Up: Function and Decorator

# %%
def calc_mean_dtd(lst):
    arr = np.array(lst)
    return arr.mean(), arr.std()

# %%
temp= (1,2,3)
print(*temp)
print(1,2,3)
# Out:
# 1 2 3
# 1 2 3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-6a96459bd811> in <module>
#       2 print(*temp)
#       3 print(1,2,3)
# ----> 4 my_func(*temp)
#
# <ipython-input-17-947fb4fc0f5b> in my_func(*arg)
#       1 def my_func(*arg):
# ----> 2     print(x)
#       3 #my_func(5,6)
#
# NameError: name 'x' is not defined

# %%
def my_func(y,*arg):
    print(arg)
    # for i in arg:
      #  print(i)
my_func(1,2,3,"a")
# Out:
# (2, 3, 'a')

# %%
my_stock = {"stock":'appl',"quantity":500,"price":150}
my_stock2 = {"bond":'bootcamp',"expiry":'2026-01-01',"min":10000}
#print(list(my_stock.keys()))
#print(list(my_stock.values()))
#print(my_stock2)
{**my_stock, **my_stock2}
# Out:
# {'stock': 'appl',
#  'quantity': 500,
#  'price': 150,
#  'bond': 'bootcamp',
#  'expiry': '2026-01-01',
#  'min': 10000}

# %%
def my_func(**args):
    print(args)
inputs = {"stock": 'appl','quantity':500,'price':150}
my_func(**inputs)
#my_func(stock='appl',quantity=500,price=150)
# Out:
# {'stock': 'appl', 'quantity': 500, 'price': 150}

# %%
def my_func(*args):
    print(args)
    
def my_debug(f):
    
    def new_func(*arg):
        print(len(arg))
        f(*arg)
        # print(arg)
    return new_func

# a_func = my_debug( my_func )
# a_func(1,2,3)

@my_debug

my_func(1,2,3)
# Out:
# 3
# (1, 2, 3)

# %%
def log_call(func):
    def wrapper(*args,**kwargs):
        print(f"Function {func,__name__} called at {datatime.now()}")
        return func(*args, **kwargs)
    return wrapper
# Out:
#   File "<ipython-input-36-f3803a796ff1>", line 1
#     def log_call(func):
#                        ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# # Data Structures Comparison
